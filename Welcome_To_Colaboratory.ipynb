# %% [markdown]
# <a href="https://colab.research.google.com/github/Abuelias2020/lab-1/blob/main/Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
low_memory=False

# %%
import matplotlib.pyplot as plt

# %%
Siraj_data=pd.read_csv("https://raw.githubusercontent.com/asukul/DS201/master/datasets/Most-Recent-Cohorts-Scorecard-Elements.csv")

# %%
Siraj_data.describe()
# Out:
#              UNITID         OPEID        OPEID6         HCM2      PREDDEG  \
# count  7.175000e+03  7.175000e+03   7175.000000  7175.000000  7175.000000
# mean   1.823310e+06  1.873706e+06  16660.384808     0.010453     1.832753
# std    6.858175e+06  3.456713e+06  14417.436704     0.101711     1.049068
# min    1.006540e+05  1.002000e+05   1002.000000     0.000000     0.000000
# 25%    1.739385e+05  3.252500e+05   3244.500000     0.000000     1.000000
# 50%    2.287230e+05  1.067400e+06  10630.000000     0.000000     2.000000
# 75%    4.494765e+05  3.010634e+06  30086.000000     0.000000     3.000000
# max    4.877820e+07  8.209884e+07  42580.000000     1.000000     4.000000
#
#            HIGHDEG      CONTROL       LOCALE         HBCU          PBI  ...  \
# count  7175.000000  7175.000000  6737.000000  6724.000000  6724.000000  ...
# mean      2.224390     2.144669    19.723171     0.015170     0.015318  ...
# ...

# %%
Siraj_data
# Out:
#         UNITID    OPEID  OPEID6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# ...        ...      ...     ...
# 7170  48305401  4224601   42246
# 7171  48387801  4223701   42237
# 7172  48400201  4228101   42281
# 7173  48414501  4232401   42324
# 7174  48778201  4221501   42215
#
#                                                  INSTNM         CITY STABBR  \
# 0                              Alabama A & M University       Normal     AL
# 1                   University of Alabama at Birmingham   Birmingham     AL
# 2                                    Amridge University   Montgomery     AL
# 3                   University of Alabama in Huntsville   Huntsville     AL
# 4                              Alabama State University   Montgomery     AL
# ...                                                 ...          ...    ...
# ...

# %%
Siraj_data.head()
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR                    INSTURL  \
# 0     AL              www.aamu.edu/
# 1     AL                www.uab.edu
# 2     AL  www.amridgeuniversity.edu
# 3     AL                www.uah.edu
# 4     AL              www.alasu.edu
#
#                                               NPCURL  HCM2  PREDDEG  ...  \
# 0      www2.aamu.edu/scripts/netpricecalc/npcalc.htm     0        3  ...
# 1           uab.studentaidcalculator.com/survey.aspx     0        3  ...
# ...

# %%
File=Siraj_data.groupby(["STABBR"]).size()

# %%
File.head()
# Out:
# STABBR
# AK      9
# AL     97
# AR     89
# AS      1
# AZ    125
# dtype: int64

# %%
AX=File.plot(kind='bar',title="No of schools per state",figsize=(10,8),legend=False,fontsize=8,sort_columns=True,color='b')
AX.set_xlabel("state",fontsize=8)
AX.set_ylabel("No of schools",fontsize=8)
plt.show()
# Out:
# <ipython-input-25-6253e349c70a>:1: FutureWarning: `sort_columns` is deprecated and will be removed in a future version.
#   AX=File.plot(kind='bar',title="No of schools per state",figsize=(10,8),legend=False,fontsize=8,sort_columns=True,color='b')
